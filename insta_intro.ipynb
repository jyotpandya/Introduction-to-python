# %%
print("My name is Jyot")
print("My favorite app is Instagram")
# Out:
# My name is Jyot
# My favorite app is Instagram

# %%
print("Welcome to Data Science with Python!")
# Out:
# Welcome to Data Science with Python!
